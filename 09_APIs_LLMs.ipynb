# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexis115/GoogleColab/blob/main/09_APIs_LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 9: Uso de la API de Google Gemini
#
# En este ejercicio vamos a aprender a utilizar la API de OpenAI

# %% [markdown]
# ## Uso básico

# %%
# !pip install python-dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.environ["GOOGLE_API_KEY"]

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="Explícame qué es machine learning en una frase"
)

print(response.text)
# Out:
# El **machine learning** es una rama de la inteligencia artificial que permite a las computadoras aprender de los datos y mejorar su rendimiento en tareas específicas sin haber sido programadas explícitamente para ellas.
